# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd()
while not (ROOT / "README.md").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent

print("Repo root:", ROOT)

UNDERSTAT_DIR = ROOT / "understat_data"
MATCHES_PATH = UNDERSTAT_DIR / "Dataset_Version_7.csv"
OUTPUT_PATH = ROOT / "data" / "processed" / "financial_dataset.csv"

MATCHES_PATH, OUTPUT_PATH
# Out:
# Repo root: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main
# (WindowsPath('C:/SFUFall2024/CMPT732/pythonProject/The-Beautiful-Game-Oracle-main/understat_data/Dataset_Version_7.csv'),
#  WindowsPath('C:/SFUFall2024/CMPT732/pythonProject/The-Beautiful-Game-Oracle-main/data/processed/financial_dataset.csv'))

# %%
df_matches = pd.read_csv(MATCHES_PATH)

df_matches = df_matches[[
    "match_id",
    "season",
    "match_date",
    "home_team_name",
    "away_team_name",
    "outcome_label",  
]]

df_matches = df_matches.rename(columns={
    "match_date": "date",
    "home_team_name": "home_team",
    "away_team_name": "away_team",
    "outcome_label": "target",
})

df_matches.head()
# Out:
#    match_id  season        date         home_team                away_team  \
# 0     18202    2022  2022-08-05    Crystal Palace                  Arsenal
# 1     18203    2022  2022-08-06            Fulham                Liverpool
# 2     18204    2022  2022-08-06       Bournemouth              Aston Villa
# 3     18205    2022  2022-08-06             Leeds  Wolverhampton Wanderers
# 4     18206    2022  2022-08-06  Newcastle United        Nottingham Forest
#
#   target
# 0      A
# 1      D
# 2      H
# 3      H
# 4      H

# %%
sorted(df_matches["home_team"].unique().tolist())
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brentford',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Fulham',
#  'Ipswich',
#  'Leeds',
#  'Leicester',
#  'Liverpool',
#  'Luton',
#  'Manchester City',
#  'Manchester United',
#  'Newcastle United',
#  'Nottingham Forest',
#  'Sheffield United',
#  'Southampton',
#  'Sunderland',
#  'Tottenham',
#  'West Ham',
#  'Wolverhampton Wanderers']

# %%
sorted(df_matches["away_team"].unique().tolist())
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brentford',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Fulham',
#  'Ipswich',
#  'Leeds',
#  'Leicester',
#  'Liverpool',
#  'Luton',
#  'Manchester City',
#  'Manchester United',
#  'Newcastle United',
#  'Nottingham Forest',
#  'Sheffield United',
#  'Southampton',
#  'Sunderland',
#  'Tottenham',
#  'West Ham',
#  'Wolverhampton Wanderers']

# %%
match_team_names = sorted(df_matches["home_team"].unique().tolist())
print("Match dataset team names:")
for n in match_team_names:
    print(" -", n)

# dict map 
TEAM_NAME_MAP = {
    # Transfermarkt names : match dataset names
    "Man City": "Manchester City",
    "Man Utd": "Manchester United",
    "Newcastle": "Newcastle United",
    "Nott'm Forest": "Nottingham Forest",
    "Wolves": "Wolverhampton Wanderers",

    # Capology names : match dataset names
    "Ipswich Town": "Ipswich",
    "Luton Town": "Luton",
    "Wolverhampton": "Wolverhampton Wanderers",
}

def normalize_team_name(name: str) -> str:
    """Map Transfermarkt/FBref Capology team names into your match dataset naming scheme."""
    if pd.isna(name):
        return name
    name = name.strip()
    return TEAM_NAME_MAP.get(name, name)
# Out:
# Match dataset team names:
#  - Arsenal
#  - Aston Villa
#  - Bournemouth
#  - Brentford
#  - Brighton
#  - Burnley
#  - Chelsea
#  - Crystal Palace
#  - Everton
#  - Fulham
#  - Ipswich
#  - Leeds
#  - Leicester
#  - Liverpool
#  - Luton
#  - Manchester City
#  - Manchester United
#  - Newcastle United
#  - Nottingham Forest
#  - Sheffield United
#  - Southampton
#  - Sunderland
#  - Tottenham
#  - West Ham
#  - Wolverhampton Wanderers

# %%
import sys
import subprocess

def pip_install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# ScraperFC 
try:
    import ScraperFC
except ImportError:
    pip_install("ScraperFC")
    import ScraperFC

from ScraperFC.transfermarkt import Transfermarkt
from ScraperFC.fbref import FBref

print("ScraperFC imported successfully.")
# Out:
# ScraperFC imported successfully.

# %%
tm = Transfermarkt()

league_code = "EPL"  

valid_seasons = tm.get_valid_seasons(league_code)
print("Valid seasons for league", league_code, ":\n", valid_seasons)
# Out:
# Valid seasons for league EPL :
#  {'25/26': '2025', '24/25': '2024', '23/24': '2023', '22/23': '2022', '21/22': '2021', '20/21': '2020', '19/20': '2019', '18/19': '2018', '17/18': '2017', '16/17': '2016', '15/16': '2015', '14/15': '2014', '13/14': '2013', '12/13': '2012', '11/12': '2011', '10/11': '2010', '09/10': '2009', '08/09': '2008', '07/08': '2007', '06/07': '2006', '05/06': '2005', '04/05': '2004', '03/04': '2003', '02/03': '2002', '01/02': '2001', '00/01': '2000', '99/00': '1999', '98/99': '1998', '97/98': '1997', '96/97': '1996', '95/96': '1995', '94/95': '1994', '93/94': '1993', '92/93': '1992'}

# %%
# Reverse map.
tm_year_to_code = {str(year): season_code for season_code, year in valid_seasons.items()}
print("\nTransfermarkt year -> season_code mapping:")
print(tm_year_to_code)

# Seasons present in matches file
match_seasons_raw = sorted(df_matches["season"].astype(str).unique().tolist())
print("\nSeasons in df_matches:", match_seasons_raw)

# map to Transfermarkt season:
season_codes_to_scrape = []
for year in match_seasons_raw:
    code = tm_year_to_code.get(year)
    if code is not None:
        season_codes_to_scrape.append(code)

season_codes_to_scrape = sorted(set(season_codes_to_scrape))
print("\nTransfermarkt season codes we will scrape:", season_codes_to_scrape)
# Out:
# Transfermarkt year -> season_code mapping:
# {'2025': '25/26', '2024': '24/25', '2023': '23/24', '2022': '22/23', '2021': '21/22', '2020': '20/21', '2019': '19/20', '2018': '18/19', '2017': '17/18', '2016': '16/17', '2015': '15/16', '2014': '14/15', '2013': '13/14', '2012': '12/13', '2011': '11/12', '2010': '10/11', '2009': '09/10', '2008': '08/09', '2007': '07/08', '2006': '06/07', '2005': '05/06', '2004': '04/05', '2003': '03/04', '2002': '02/03', '2001': '01/02', '2000': '00/01', '1999': '99/00', '1998': '98/99', '1997': '97/98', '1996': '96/97', '1995': '95/96', '1994': '94/95', '1993': '93/94', '1992': '92/93'}
#
# Seasons in df_matches: ['2022', '2023', '2024', '2025']
#
# Transfermarkt season codes we will scrape: ['22/23', '23/24', '24/25', '25/26']

# %%
import os

CACHE_DIR = ROOT / "data" / "external" / "tm_players_cache"
CACHE_DIR.mkdir(parents=True, exist_ok=True)

def scrape_or_load_players(year_code, league_code="EPL"):
    # FIX: Replace slash in season code
    safe_code = year_code.replace("/", "_")

    cache_path = CACHE_DIR / f"tm_players_{league_code}_{safe_code}.pkl"

    if cache_path.exists():
        print(f"Loading players from cache for {league_code} {year_code}: {cache_path}")
        return pd.read_pickle(cache_path)

    print(f"Scraping players for {league_code} {year_code} (no cache yet)...")
    players_df = tm.scrape_players(year=year_code, league=league_code)
    print("Scraped rows:", len(players_df))

    try:
        players_df.to_pickle(cache_path)
        print("Saved cache to:", cache_path)
    except Exception as e:
        print("Warning: could not cache players due to:", repr(e))

    return players_df

# %%
season_codes_to_scrape = ['22/23', '23/24', '24/25', '25/26'] #for now to just test

import numpy as np

def parse_market_value(value):
    """
    Convert market value strings like '€50.0m' or '€800k' to numeric EUR.
    """
    if isinstance(value, (int, float, np.number)):
        return float(value)
    if not isinstance(value, str):
        return np.nan

    s = value.replace("€", "").replace(",", "").strip().lower()
    factor = 1.0
    if s.endswith("m"):
        factor = 1e6
        s = s[:-1]
    elif s.endswith("k"):
        factor = 1e3
        s = s[:-1]

    try:
        return float(s) * factor
    except ValueError:
        return np.nan


def scrape_club_season_values_tm(season_codes, league_code="EPL"):
    """
    For each Transfermarkt season code (e.g., '22/23'),
    use cached player data if available, otherwise scrape once.
    Aggregate to club-season squad_value_eur / avg_player_value_eur / squad_size,
    after deduplicating players per (ID, Team).
    """
    all_records = []

    for code in season_codes:
        print(f"\n=== Processing season code {code} ===")
        players_df = scrape_or_load_players(code, league_code=league_code)

        team_col = "Team"
        value_col = "Value"

        # Keep only relevant columns
        cols_to_keep = [team_col, value_col, "ID"]
        if "Value last updated" in players_df.columns:
            cols_to_keep.append("Value last updated")

        df = players_df[cols_to_keep].dropna(subset=[team_col, value_col, "ID"]).copy()

        # Deduplicate: one row per (ID, Team), keep the latest if we have a timestamp
        if "Value last updated" in df.columns:
            df = df.sort_values("Value last updated")
        df = df.drop_duplicates(subset=["ID", team_col], keep="last")

        # Parse market values to numeric euros
        df[value_col] = df[value_col].apply(parse_market_value)

        grouped = df.groupby(team_col).agg(
            squad_value_eur=(value_col, "sum"),
            avg_player_value_eur=(value_col, "mean"),
            squad_size=(value_col, "count"),
        ).reset_index()

        grouped["season_code"] = code  # '22/23', '23/24', '24/25', '25/26'
        grouped["season"] = grouped["season_code"].map(valid_seasons).astype(str)
        grouped = grouped.rename(columns={team_col: "team_tm"})
        all_records.append(grouped)

    return pd.concat(all_records, ignore_index=True)

# %%
team_season_fin_tm = scrape_club_season_values_tm(season_codes_to_scrape, league_code=league_code)
team_season_fin_tm.head(20)
# Out:
# === Processing season code 22/23 ===
# Loading players from cache for EPL 22/23: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\external\tm_players_cache\tm_players_EPL_22_23.pkl
#
# === Processing season code 23/24 ===
# Loading players from cache for EPL 23/24: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\external\tm_players_cache\tm_players_EPL_23_24.pkl
#
# === Processing season code 24/25 ===
# Loading players from cache for EPL 24/25: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\external\tm_players_cache\tm_players_EPL_24_25.pkl
#
# === Processing season code 25/26 ===
# Loading players from cache for EPL 25/26: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\external\tm_players_cache\tm_players_EPL_25_26.pkl
#           team_tm  squad_value_eur  avg_player_value_eur  squad_size  \
# 0   A. Klagenfurt         125000.0          1.250000e+05           1
# 1        AC Milan       92000000.0          3.066667e+07           3
# 2    ADO Den Haag         275000.0          2.750000e+05           1
# 3      AEK Athens        2500000.0          2.500000e+06           1
# 4   AFC Wimbledon         275000.0          2.750000e+05           1
# 5      AJ Auxerre        5000000.0          5.000000e+06           1
# 6     Aberdeen FC         700000.0          7.000000e+05           1
# 7            Ajax        4000000.0          4.000000e+06           1
# 8         Al-Ahli       38000000.0          1.266667e+07           3
# 9      Al-Ahli SC        4000000.0          4.000000e+06           1
# 10    Al-Arabi SC        5000000.0          5.000000e+06           1
# 11     Al-Ettifaq        3000000.0          3.000000e+06           1
# 12     Al-Gharafa        4000000.0          4.000000e+06           1
# 13       Al-Hilal       91000000.0          2.275000e+07           4
# 14     Al-Ittihad       20000000.0          1.000000e+07           2
# 15      Al-Jazira        1800000.0          1.800000e+06           1
# 16        Al-Nasr         800000.0          8.000000e+05           1
# 17       Al-Nassr       32000000.0          1.600000e+07           2
# 18      Al-Rayyan       21500000.0          1.075000e+07           2
# 19        Al-Sadd        5000000.0          5.000000e+06           1
#
#    season_code season
# 0        22/23   2022
# 1        22/23   2022
# 2        22/23   2022
# 3        22/23   2022
# 4        22/23   2022
# 5        22/23   2022
# 6        22/23   2022
# 7        22/23   2022
# 8        22/23   2022
# 9        22/23   2022
# 10       22/23   2022
# 11       22/23   2022
# 12       22/23   2022
# 13       22/23   2022
# 14       22/23   2022
# 15       22/23   2022
# 16       22/23   2022
# 17       22/23   2022
# 18       22/23   2022
# 19       22/23   2022

# %%
players_df = scrape_or_load_players("25/26", "EPL")
players_df.head()
# Out:
# Loading players from cache for EPL 25/26: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\external\tm_players_cache\tm_players_EPL_25_26.pkl
#               Name      ID    Value Value last updated           DOB Age  \
# 0  Tino Livramento  503981  €40.00m       May 30, 2025  Nov 12, 2002  23
# 1       Malo Gusto  620322  €35.00m       May 30, 2025  May 19, 2003  22
# 2      John McGinn  193116  €16.00m       May 30, 2025  Oct 18, 1994  31
# 3   Tim Iroegbunam  696589  €11.00m       Oct 17, 2025  Jun 30, 2003  22
# 4        Joe Rodon  297212  €10.00m       May 27, 2025  Oct 22, 1997  28
#
#   Height (m) Nationality Citizenship          Position Other positions  \
# 0       1.82     England          []        Right-Back            None
# 1       1.78      France          []        Right-Back            None
# 2       1.78    Scotland          []  Central Midfield            None
# 3       1.83     England          []  Central Midfield            None
# 4       1.93       Wales     [Wales]       Centre-Back            None
#
#           Team Last club Since        Joined Contract expiration  \
# 0    Newcastle      None  None   Aug 8, 2023        Jun 30, 2028
# 1      Chelsea      None  None  Jan 29, 2023        Jun 30, 2030
# 2  Aston Villa      None  None   Aug 8, 2018        Jun 30, 2028
# 3      Everton      None  None   Jul 1, 2024        Jun 30, 2027
# 4        Leeds      None  None   Jul 2, 2024        Jun 30, 2028
#
#   Market value history                                   Transfer history
# 0                 None  Empty DataFrame
# Columns: [Season, Date, Left, ...
# 1                 None  Empty DataFrame
# Columns: [Season, Date, Left, ...
# 2                 None  Empty DataFrame
# Columns: [Season, Date, Left, ...
# 3                 None  Empty DataFrame
# Columns: [Season, Date, Left, ...
# 4                 None  Empty DataFrame
# Columns: [Season, Date, Left, ...

# %%
from ScraperFC.capology import Capology

cap = Capology()

league_code = "EPL" 

# Available seasons Capology 
cap_valid_seasons = cap.get_valid_seasons(league_code)
print("Capology valid seasons for", league_code, ":", cap_valid_seasons)

# Seasons present in dataset
match_seasons = sorted(df_matches["season"].astype(str).unique().tolist())
print("Match seasons:", match_seasons)

# Capology seasons that match dataset
cap_seasons_to_scrape = []
for s in cap_valid_seasons:
    for year in match_seasons:
        if year in s:   # '2024' in '24/25' or '2024-2025'
            cap_seasons_to_scrape.append(s)

cap_seasons_to_scrape = sorted(set(cap_seasons_to_scrape))
# cap_seasons_to_scrape = ['2025-26'] # test 
print("Capology seasons we will scrape:", cap_seasons_to_scrape)
# Out:
# Capology valid seasons for EPL : ['2025-26', '2024-25', '2023-24', '2022-23', '2021-22', '2020-21', '2019-20', '2018-19', '2017-18', '2016-17', '2015-16', '2014-15', '2013-14']
# Match seasons: ['2022', '2023', '2024', '2025']
# Capology seasons we will scrape: ['2022-23', '2023-24', '2024-25', '2025-26']

# %%
# Cache for Capology salaries 
CAPOLOGY_CACHE_DIR = ROOT / "data" / "external" / "capology_cache"
CAPOLOGY_CACHE_DIR.mkdir(parents=True, exist_ok=True)

print("Capology cache dir:", CAPOLOGY_CACHE_DIR)

def capology_scrape_or_load(year_code, league_code="EPL", currency="eur"):
    """
    Load Capology salaries for (league, year_code) from cache if present.
    Otherwise scrape once and save to disk.
    """
    cache_path = CAPOLOGY_CACHE_DIR / f"capology_salaries_{league_code}_{year_code}.csv"

    if cache_path.exists():
        print(f"Loading Capology salaries from cache: {cache_path}")
        return pd.read_csv(cache_path)

    print(f"Scraping Capology salaries for {league_code} {year_code} (no cache yet)...")
    sal_df = cap.scrape_salaries(year=year_code, league=league_code, currency=currency)
    print("Scraped rows:", len(sal_df))

    sal_df.to_csv(cache_path, index=False)
    print("Saved Capology cache →", cache_path)

    return sal_df
# Out:
# Capology cache dir: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\external\capology_cache

# %%
import numpy as np

def parse_salary_eur(x):
    """
    parser for salary values 
    if it's already numeric, just float() it.
    if it's a string with commas or currency symbols, strip & parse.
    """
    if isinstance(x, (int, float, np.number)):
        return float(x)
    if not isinstance(x, str):
        return np.nan

    s = x.replace("€", "").replace(",", "").strip().lower()
    try:
        return float(s)
    except ValueError:
        return np.nan

# %%
def scrape_club_season_wages_capology(season_codes, league_code="EPL", currency="eur"):
    """
    For each season code,
    load cached salary data if available, otherwise scrape once.
    aggregate to team-season wage bill and avg salary.
    """
    all_records = []

    for code in season_codes:
        print(f"\n=== Processing Capology season {code} ===")

        # Load with caching
        sal_df = capology_scrape_or_load(code, league_code=league_code, currency=currency)
        print("Original columns:", sal_df.columns.tolist())

        # If CSV, the second header row is now row 0 of the DataFrame
        # first row:
        first_row = sal_df.iloc[0]
        print("First row (potential sub-header):")
        print(first_row.to_dict())

        # Build new column names by combining the column name + the first-row entry
        new_cols = []
        for col in sal_df.columns:
            top = str(col).strip()
            sub = str(first_row[col]).strip()
            if sub and sub.lower() != "nan":
                name = f"{top} {sub}".replace("\n", " ").strip()
            else:
                name = top
            new_cols.append(name)

        # Drop the first row (it was the second header), assign new column names
        sal_df = sal_df.iloc[1:].copy()
        sal_df.columns = new_cols

        print("Reconstructed columns:", sal_df.columns.tolist())

        # Team column: anything with 'CLUB' in the name
        team_col_candidates = [c for c in sal_df.columns if "club" in c.lower()]
        print("Team column candidates:", team_col_candidates)
        if not team_col_candidates:
            raise ValueError("Could not find a 'CLUB' column in Capology data.")
        team_col = team_col_candidates[0]

        # Salary column: something like 'EST. BASE SALARY GROSS P/Y (EUR)'
        salary_col_candidates = [
            c for c in sal_df.columns
            if "base" in c.lower() and "gross" in c.lower() and "p/y" in c.lower()
        ]
        print("Salary column candidates:", salary_col_candidates)
        if not salary_col_candidates:
            # Fallback: any column with 'GROSS P/Y' or 'P/Y' that looks numeric
            salary_col_candidates = [
                c for c in sal_df.columns
                if "gross" in c.lower() and "p/y" in c.lower()
            ]
            print("Fallback salary column candidates:", salary_col_candidates)

        if not salary_col_candidates:
            raise ValueError("Could not find a yearly base salary column in Capology data.")
        salary_col = salary_col_candidates[0]

        # Keep only team + salary
        df = sal_df[[team_col, salary_col]].dropna().copy()
        df[salary_col] = df[salary_col].apply(parse_salary_eur)

        # Aggregate to team-season wage bill
        grouped = df.groupby(team_col).agg(
            wage_bill_eur=(salary_col, "sum"),
            avg_salary_eur=(salary_col, "mean"),
            player_count=(salary_col, "count"),
        ).reset_index()

        grouped["season_code_cap"] = code

        # Map Capology season code -> your numeric season (e.g. '2025-26' -> '2025')
        def infer_season_year(s):
            for y in match_seasons:
                if y in s:
                    return y
            return None

        grouped["season"] = grouped["season_code_cap"].apply(infer_season_year).astype(str)
        grouped = grouped.rename(columns={team_col: "team_cap"})

        all_records.append(grouped)

    return pd.concat(all_records, ignore_index=True)

# %%
team_season_wages = scrape_club_season_wages_capology(
    cap_seasons_to_scrape,
    league_code=league_code,
    currency="eur",
)

team_season_wages.head()
# Out:
# === Processing Capology season 2022-23 ===
# Loading Capology salaries from cache: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\external\capology_cache\capology_salaries_EPL_2022-23.csv
# Original columns: ['Unnamed: 0', 'EST. BASE SALARY', 'EST. BASE SALARY.1', 'EST. BASE SALARY.2', 'BIO', 'BIO.1', 'BIO.2', 'Unnamed: 7']
# First row (potential sub-header):
# {'Unnamed: 0': 'PLAYER', 'EST. BASE SALARY': 'GROSS P/W\n(EUR)', 'EST. BASE SALARY.1': 'GROSS P/Y\n(EUR)', 'EST. BASE SALARY.2': 'ADJ. GROSS\n(EUR)', 'BIO': 'POS.', 'BIO.1': 'AGE', 'BIO.2': 'COUNTRY', 'Unnamed: 7': 'CLUB'}
# Reconstructed columns: ['Unnamed: 0 PLAYER', 'EST. BASE SALARY GROSS P/W (EUR)', 'EST. BASE SALARY.1 GROSS P/Y (EUR)', 'EST. BASE SALARY.2 ADJ. GROSS (EUR)', 'BIO POS.', 'BIO.1 AGE', 'BIO.2 COUNTRY', 'Unnamed: 7 CLUB']
# Team column candidates: ['Unnamed: 7 CLUB']
# Salary column candidates: ['EST. BASE SALARY.1 GROSS P/Y (EUR)']
#
# === Processing Capology season 2023-24 ===
# Loading Capology salaries from cache: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\external\capology_cache\capology_salaries_EPL_2023-24.csv
# Original columns: ['Unnamed: 0', 'EST. BASE SALARY', 'EST. BASE SALARY.1', 'EST. BASE SALARY.2', 'BIO', 'BIO.1', 'BIO.2', 'Unnamed: 7']
# First row (potential sub-header):
# {'Unnamed: 0': 'PLAYER', 'EST. BASE SALARY': 'GROSS P/W\n(EUR)', 'EST. BASE SALARY.1': 'GROSS P/Y\n(EUR)', 'EST. BASE SALARY.2': 'ADJ. GROSS\n(EUR)', 'BIO': 'POS.', 'BIO.1': 'AGE', 'BIO.2': 'COUNTRY', 'Unnamed: 7': 'CLUB'}
# Reconstructed columns: ['Unnamed: 0 PLAYER', 'EST. BASE SALARY GROSS P/W (EUR)', 'EST. BASE SALARY.1 GROSS P/Y (EUR)', 'EST. BASE SALARY.2 ADJ. GROSS (EUR)', 'BIO POS.', 'BIO.1 AGE', 'BIO.2 COUNTRY', 'Unnamed: 7 CLUB']
# Team column candidates: ['Unnamed: 7 CLUB']
# Salary column candidates: ['EST. BASE SALARY.1 GROSS P/Y (EUR)']
#
# === Processing Capology season 2024-25 ===
# Loading Capology salaries from cache: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\external\capology_cache\capology_salaries_EPL_2024-25.csv
# Original columns: ['Unnamed: 0', 'EST. BASE SALARY', 'EST. BASE SALARY.1', 'EST. BASE SALARY.2', 'BIO', 'BIO.1', 'BIO.2', 'Unnamed: 7']
# First row (potential sub-header):
# {'Unnamed: 0': 'PLAYER', 'EST. BASE SALARY': 'GROSS P/W\n(EUR)', 'EST. BASE SALARY.1': 'GROSS P/Y\n(EUR)', 'EST. BASE SALARY.2': 'ADJ. GROSS\n(EUR)', 'BIO': 'POS.', 'BIO.1': 'AGE', 'BIO.2': 'COUNTRY', 'Unnamed: 7': 'CLUB'}
# Reconstructed columns: ['Unnamed: 0 PLAYER', 'EST. BASE SALARY GROSS P/W (EUR)', 'EST. BASE SALARY.1 GROSS P/Y (EUR)', 'EST. BASE SALARY.2 ADJ. GROSS (EUR)', 'BIO POS.', 'BIO.1 AGE', 'BIO.2 COUNTRY', 'Unnamed: 7 CLUB']
# Team column candidates: ['Unnamed: 7 CLUB']
# Salary column candidates: ['EST. BASE SALARY.1 GROSS P/Y (EUR)']
#
# === Processing Capology season 2025-26 ===
# Loading Capology salaries from cache: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\external\capology_cache\capology_salaries_EPL_2025-26.csv
# Original columns: ['Unnamed: 0', 'Unnamed: 1', 'EST. BASE SALARY', 'EST. BASE SALARY.1', 'EST. BONUS', 'CONTRACT DETAILS', 'CONTRACT DETAILS.1', 'CONTRACT DETAILS.2', 'CONTRACT DETAILS.3', 'CONTRACT DETAILS.4', 'BIO', 'BIO.1', 'BIO.2', 'BIO.3', 'BIO.4', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17']
# First row (potential sub-header):
# {'Unnamed: 0': 'PLAYER', 'Unnamed: 1': nan, 'EST. BASE SALARY': 'GROSS P/W\n(EUR)', 'EST. BASE SALARY.1': 'GROSS P/Y\n(EUR)', 'EST. BONUS': 'GROSS P/Y\n(EUR)', 'CONTRACT DETAILS': 'SIGNED', 'CONTRACT DETAILS.1': 'EXPIRATION', 'CONTRACT DETAILS.2': 'YEARS REMAINING', 'CONTRACT DETAILS.3': 'GROSS REMAINING\n(EUR)', 'CONTRACT DETAILS.4': 'RELEASE CLAUSE\n(EUR)', 'BIO': 'STATUS', 'BIO.1': 'POS.', 'BIO.2': 'POS.', 'BIO.3': 'AGE', 'BIO.4': 'COUNTRY', 'Unnamed: 15': 'CLUB', 'Unnamed: 16': 'ACTIVE', 'Unnamed: 17': 'LOAN'}
# Reconstructed columns: ['Unnamed: 0 PLAYER', 'Unnamed: 1', 'EST. BASE SALARY GROSS P/W (EUR)', 'EST. BASE SALARY.1 GROSS P/Y (EUR)', 'EST. BONUS GROSS P/Y (EUR)', 'CONTRACT DETAILS SIGNED', 'CONTRACT DETAILS.1 EXPIRATION', 'CONTRACT DETAILS.2 YEARS REMAINING', 'CONTRACT DETAILS.3 GROSS REMAINING (EUR)', 'CONTRACT DETAILS.4 RELEASE CLAUSE (EUR)', 'BIO STATUS', 'BIO.1 POS.', 'BIO.2 POS.', 'BIO.3 AGE', 'BIO.4 COUNTRY', 'Unnamed: 15 CLUB', 'Unnamed: 16 ACTIVE', 'Unnamed: 17 LOAN']
# Team column candidates: ['Unnamed: 15 CLUB']
# Salary column candidates: ['EST. BASE SALARY.1 GROSS P/Y (EUR)']
#       team_cap  wage_bill_eur  avg_salary_eur  player_count season_code_cap  \
# 0      Arsenal    150624114.0    5.793235e+06            26         2022-23
# 1  Aston Villa    123236470.0    4.107882e+06            30         2022-23
# 2  Bournemouth     57529223.0    1.743310e+06            33         2022-23
# 3    Brentford     43456057.0    1.671387e+06            26         2022-23
# 4     Brighton     50816499.0    1.954481e+06            26         2022-23
#
#   season
# 0   2022
# 1   2022
# 2   2022
# 3   2022
# 4   2022

# %%
print("Transfermarkt team names:")
print(sorted(team_season_fin_tm["team_tm"].unique().tolist()))

print("\nCapology team names:")
print(sorted(team_season_wages["team_cap"].unique().tolist()))
# Out:
# Transfermarkt team names:
# ["1.FC K'lautern", 'A. Klagenfurt', 'AC Milan', 'ADO Den Haag', 'AE Kifisias', 'AEK Athens', 'AFC Wimbledon', 'AJ Auxerre', 'Aberdeen FC', 'Ajax', 'Al-Ahli', 'Al-Ahli SC', 'Al-Arabi SC', 'Al-Dhafra FC', 'Al-Ettifaq', 'Al-Gharafa', 'Al-Hilal', 'Al-Ittihad', 'Al-Jazira', 'Al-Nasr', 'Al-Nassr', 'Al-Rayyan', 'Al-Sadd', 'Al-Shabab', 'Al-Taawoun', 'Alanyaspor', 'Alavés', 'Altrincham', 'Alverca', 'Amed SK', 'América', 'Aris Limassol', 'Arouca', 'Arsenal', 'Arsenal U21', 'Aston Villa', 'Aston Villa U18', 'Aston Villa U21', 'Atalanta', 'Athletic Club', 'Atlanta', 'Atlético', 'Atlético-MG', 'Augsburg', 'Barcelona', 'Barnet', 'Barnsley', 'Basel', 'Bayern Munich', 'Beerschot VA', 'Besiktas', 'Birmingham', 'Blackburn', 'Blackpool', 'Bohemians', 'Bologna', 'Bolton', 'Botafogo', 'Botev Plovdiv', 'Bournemouth', 'Bournemouth U21', 'Bradford', 'Braga', 'Brentford', 'Brentford B', 'Brighton', 'Brighton U21', 'Bristol City', 'Bristol Rovers', 'Burnley', 'Burton Albion', 'C. Rizespor', 'CFR Cluj', 'CSKA Sofia', 'Cagliari', 'Cambridge Utd.', 'Cardiff', 'Cavalry FC', 'Celta de Vigo', 'Celtic', 'Central Coast', 'Charlotte', 'Charlton', 'Chelsea', 'Chelsea U21', 'Chesterfield', 'Club Brugge', 'Colchester Utd.', 'Colorado', 'Como', 'Copenhagen', 'Coventry', 'Cracovia', 'Crawley Town', 'Cremonese', 'Crewe Alexandra', 'Cruzeiro', 'Crystal Palace', 'CyD Leonesa', 'Derby', 'Dijon', 'Dinamo Zagreb', 'Doncaster', 'Dortmund', 'Dundee FC', 'Dunfermline A.', 'Eastleigh', 'Elche CF', 'Espanyol', 'Esteghlal FC', 'Estoril', 'Estoril U23', 'Everton', 'Everton U21', 'Exeter City', 'FC Annecy', 'FC Baniyas', 'FC Cartagena', 'FC Dinamo', 'FC Groningen', 'FC Lorient', 'FC Metz', 'FC Schalke 04', 'FC Seoul', 'FC Thun', 'FCV Dender EH', 'Falkirk', 'Fenerbahçe', 'Ferencváros', 'Feyenoord', 'Fiorentina', 'Flamengo', 'Fluminense', 'Fortuna Sittard', 'Frankfurt', 'Fulham', 'Galatasaray', 'Galway United', 'Genoa', 'Girona', 'Glentoran', 'Grasshoppers', 'Grêmio', 'HNK Rijeka', 'Hajduk Split', 'Hamburg', 'Harrogate Town', 'Hellas Verona', 'Hibernian FC', 'Hoffenheim', 'Huddersfield', 'Hull City', 'Inter', 'Ipswich', 'Juventus', 'Kalba FC', 'Kanchanaburi FC', 'Karagümrük', 'Kasimpasa', 'Kilmarnock FC', 'Kocaelispor', 'LA Galaxy', 'LAFC', 'LASK', 'Lausanne-Sport', 'Lazio', 'Leeds', 'Legia Warszawa', 'Leicester', 'Leicester U21', 'Leipzig', 'Lens', 'Leverkusen', 'Leyton Orient', 'Lille', 'Lincoln City', 'Linfield', 'Liverpool', 'Liverpool U21', 'Livingston FC', 'Luton', 'Lyon', 'Malmö', 'Man City', 'Man City U21', 'Man Utd', 'Man Utd U21', 'Mansfield Town', 'Marseille', 'Middlesbrough', 'Midtjylland', 'Milan Futuro', 'Millwall', 'Monaco', 'Monterrey', 'Montréal', 'Monza', 'Morecambe FC', 'Moreirense', 'Morton', 'Motherwell FC', 'Mönchengladbach', 'NEOM SC', 'NK Celje', 'Napoli', 'Nashville', 'New England', 'Newcastle', 'Newcastle U21', 'Newport County', 'Nice', 'Northampton', 'Norwich', "Nott'm Forest", 'Notts County', 'Novi Pazar', 'Oldham Athletic', 'Olympiacos', 'Olympiacos B', 'Omonia Nicosia', 'Oxford United', 'PAOK', 'PEC Zwolle', 'PSG', 'PSV', 'Pafos', 'Palermo', 'Palmeiras', 'Panathinaikos', 'Persepolis FC', 'Peterborough', 'Plymouth', 'Pogon Szczecin', 'Port Vale', 'Porto', 'Portsmouth', 'Preston', 'QPR', 'R. Strasbourg', 'RCD Mallorca', 'RSC Anderlecht', 'Radomiak', 'Raków', 'Rangers', 'Reading', 'Real Betis', 'Real Madrid', 'Real Oviedo', 'Real Sociedad', 'Real Valladolid', 'Red Star FC', 'Rio Ave', 'River Plate', 'Roma', 'Rosario Central', 'Rotherham', 'Royal Antwerp', 'Saint-Étienne', 'Salford', 'San Diego', 'Sassuolo', 'Sevilla FC', 'Sheff Utd', 'Sheff Utd U21', 'Sheff Wed', 'Shelbourne', 'Slask Wroclaw', 'Slavia Praha', 'Southampton', 'Southampton U21', 'Sporting', 'Sporting B', 'St. Mirren', "St. Pat's", 'St. Pauli', 'Standard Liège', 'Stevenage', 'Stockport', 'Stoke City', 'Stuttg. Kickers', 'Stuttgart', 'Sunderland', 'Swansea', 'Swindon Town', 'São Paulo', 'Ternana', 'Tondela', 'Torino', 'Toronto', 'Tottenham', 'Tottenham U21', 'Toulouse', 'Trabzonspor', 'Tranmer ...
#
# Capology team names:
# ['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton', 'Burnley', 'Chelsea', 'Crystal Palace', 'Everton', 'Fulham', 'Ipswich Town', 'Leeds', 'Leicester', 'Liverpool', 'Luton Town', 'Manchester City', 'Manchester United', 'Newcastle', 'Nottingham Forest', 'Sheffield United', 'Southampton', 'Sunderland', 'Tottenham', 'West Ham', 'Wolverhampton']

# %%
team_season_fin_tm["team"] = team_season_fin_tm["team_tm"].apply(normalize_team_name)
team_season_wages["team"] = team_season_wages["team_cap"].apply(normalize_team_name)

print("TM normalized teams:")
print(sorted(team_season_fin_tm["team"].unique().tolist()))

print("\nCapology normalized teams:")
print(sorted(team_season_wages["team"].unique().tolist()))

print("\nMatch dataset teams:")
print(sorted(df_matches["home_team"].unique().tolist()))
# Out:
# TM normalized teams:
# ["1.FC K'lautern", 'A. Klagenfurt', 'AC Milan', 'ADO Den Haag', 'AE Kifisias', 'AEK Athens', 'AFC Wimbledon', 'AJ Auxerre', 'Aberdeen FC', 'Ajax', 'Al-Ahli', 'Al-Ahli SC', 'Al-Arabi SC', 'Al-Dhafra FC', 'Al-Ettifaq', 'Al-Gharafa', 'Al-Hilal', 'Al-Ittihad', 'Al-Jazira', 'Al-Nasr', 'Al-Nassr', 'Al-Rayyan', 'Al-Sadd', 'Al-Shabab', 'Al-Taawoun', 'Alanyaspor', 'Alavés', 'Altrincham', 'Alverca', 'Amed SK', 'América', 'Aris Limassol', 'Arouca', 'Arsenal', 'Arsenal U21', 'Aston Villa', 'Aston Villa U18', 'Aston Villa U21', 'Atalanta', 'Athletic Club', 'Atlanta', 'Atlético', 'Atlético-MG', 'Augsburg', 'Barcelona', 'Barnet', 'Barnsley', 'Basel', 'Bayern Munich', 'Beerschot VA', 'Besiktas', 'Birmingham', 'Blackburn', 'Blackpool', 'Bohemians', 'Bologna', 'Bolton', 'Botafogo', 'Botev Plovdiv', 'Bournemouth', 'Bournemouth U21', 'Bradford', 'Braga', 'Brentford', 'Brentford B', 'Brighton', 'Brighton U21', 'Bristol City', 'Bristol Rovers', 'Burnley', 'Burton Albion', 'C. Rizespor', 'CFR Cluj', 'CSKA Sofia', 'Cagliari', 'Cambridge Utd.', 'Cardiff', 'Cavalry FC', 'Celta de Vigo', 'Celtic', 'Central Coast', 'Charlotte', 'Charlton', 'Chelsea', 'Chelsea U21', 'Chesterfield', 'Club Brugge', 'Colchester Utd.', 'Colorado', 'Como', 'Copenhagen', 'Coventry', 'Cracovia', 'Crawley Town', 'Cremonese', 'Crewe Alexandra', 'Cruzeiro', 'Crystal Palace', 'CyD Leonesa', 'Derby', 'Dijon', 'Dinamo Zagreb', 'Doncaster', 'Dortmund', 'Dundee FC', 'Dunfermline A.', 'Eastleigh', 'Elche CF', 'Espanyol', 'Esteghlal FC', 'Estoril', 'Estoril U23', 'Everton', 'Everton U21', 'Exeter City', 'FC Annecy', 'FC Baniyas', 'FC Cartagena', 'FC Dinamo', 'FC Groningen', 'FC Lorient', 'FC Metz', 'FC Schalke 04', 'FC Seoul', 'FC Thun', 'FCV Dender EH', 'Falkirk', 'Fenerbahçe', 'Ferencváros', 'Feyenoord', 'Fiorentina', 'Flamengo', 'Fluminense', 'Fortuna Sittard', 'Frankfurt', 'Fulham', 'Galatasaray', 'Galway United', 'Genoa', 'Girona', 'Glentoran', 'Grasshoppers', 'Grêmio', 'HNK Rijeka', 'Hajduk Split', 'Hamburg', 'Harrogate Town', 'Hellas Verona', 'Hibernian FC', 'Hoffenheim', 'Huddersfield', 'Hull City', 'Inter', 'Ipswich', 'Juventus', 'Kalba FC', 'Kanchanaburi FC', 'Karagümrük', 'Kasimpasa', 'Kilmarnock FC', 'Kocaelispor', 'LA Galaxy', 'LAFC', 'LASK', 'Lausanne-Sport', 'Lazio', 'Leeds', 'Legia Warszawa', 'Leicester', 'Leicester U21', 'Leipzig', 'Lens', 'Leverkusen', 'Leyton Orient', 'Lille', 'Lincoln City', 'Linfield', 'Liverpool', 'Liverpool U21', 'Livingston FC', 'Luton', 'Lyon', 'Malmö', 'Man City U21', 'Man Utd U21', 'Manchester City', 'Manchester United', 'Mansfield Town', 'Marseille', 'Middlesbrough', 'Midtjylland', 'Milan Futuro', 'Millwall', 'Monaco', 'Monterrey', 'Montréal', 'Monza', 'Morecambe FC', 'Moreirense', 'Morton', 'Motherwell FC', 'Mönchengladbach', 'NEOM SC', 'NK Celje', 'Napoli', 'Nashville', 'New England', 'Newcastle U21', 'Newcastle United', 'Newport County', 'Nice', 'Northampton', 'Norwich', 'Nottingham Forest', 'Notts County', 'Novi Pazar', 'Oldham Athletic', 'Olympiacos', 'Olympiacos B', 'Omonia Nicosia', 'Oxford United', 'PAOK', 'PEC Zwolle', 'PSG', 'PSV', 'Pafos', 'Palermo', 'Palmeiras', 'Panathinaikos', 'Persepolis FC', 'Peterborough', 'Plymouth', 'Pogon Szczecin', 'Port Vale', 'Porto', 'Portsmouth', 'Preston', 'QPR', 'R. Strasbourg', 'RCD Mallorca', 'RSC Anderlecht', 'Radomiak', 'Raków', 'Rangers', 'Reading', 'Real Betis', 'Real Madrid', 'Real Oviedo', 'Real Sociedad', 'Real Valladolid', 'Red Star FC', 'Rio Ave', 'River Plate', 'Roma', 'Rosario Central', 'Rotherham', 'Royal Antwerp', 'Saint-Étienne', 'Salford', 'San Diego', 'Sassuolo', 'Sevilla FC', 'Sheff Utd', 'Sheff Utd U21', 'Sheff Wed', 'Shelbourne', 'Slask Wroclaw', 'Slavia Praha', 'Southampton', 'Southampton U21', 'Sporting', 'Sporting B', 'St. Mirren', "St. Pat's", 'St. Pauli', 'Standard Liège', 'Stevenage', 'Stockport', 'Stoke City', 'Stuttg. Kickers', 'Stuttgart', 'Sunderland', 'Swansea', 'Swindon Town', 'São Paulo', 'Ternana', 'Tondela', 'Torino', 'Toronto', 'Tottenham', 'Tottenham U21', 'Toulou ...
#
# Capology normalized teams:
# ['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton', 'Burnley', 'Chelsea', 'Crystal Palace', 'Everton', 'Fulham', 'Ipswich', 'Leeds', 'Leicester', 'Liverpool', 'Luton', 'Manchester City', 'Manchester United', 'Newcastle United', 'Nottingham Forest', 'Sheffield United', 'Southampton', 'Sunderland', 'Tottenham', 'West Ham', 'Wolverhampton Wanderers']
#
# Match dataset teams:
# ['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton', 'Burnley', 'Chelsea', 'Crystal Palace', 'Everton', 'Fulham', 'Ipswich', 'Leeds', 'Leicester', 'Liverpool', 'Luton', 'Manchester City', 'Manchester United', 'Newcastle United', 'Nottingham Forest', 'Sheffield United', 'Southampton', 'Sunderland', 'Tottenham', 'West Ham', 'Wolverhampton Wanderers']

# %%
team_season_fin_tm["season"] = team_season_fin_tm["season"].astype(str)
team_season_wages["season"] = team_season_wages["season"].astype(str)

tm_fin = team_season_fin_tm[[
    "season",
    "team",
    "squad_value_eur",
    "avg_player_value_eur",
    "squad_size",
]]

wages_fin = team_season_wages[[
    "season",
    "team",
    "wage_bill_eur",
    "avg_salary_eur",
    "player_count",
]]

# Merge Transfermarkt + Capology at (season, team)
club_season_fin = tm_fin.merge(
    wages_fin,
    how="outer",     # outer so we keep teams even if one source is missing
    on=["season", "team"],
    validate="1:1",
)

print("Club-season financial shape:", club_season_fin.shape)
club_season_fin.head()
# Out:
# Club-season financial shape: (679, 8)
#   season           team  squad_value_eur  avg_player_value_eur  squad_size  \
# 0   2022  A. Klagenfurt         125000.0          1.250000e+05         1.0
# 1   2022       AC Milan       92000000.0          3.066667e+07         3.0
# 2   2022   ADO Den Haag         275000.0          2.750000e+05         1.0
# 3   2022     AEK Athens        2500000.0          2.500000e+06         1.0
# 4   2022  AFC Wimbledon         275000.0          2.750000e+05         1.0
#
#    wage_bill_eur  avg_salary_eur  player_count
# 0            NaN             NaN           NaN
# 1            NaN             NaN           NaN
# 2            NaN             NaN           NaN
# 3            NaN             NaN           NaN
# 4            NaN             NaN           NaN

# %%
df_matches["season"] = df_matches["season"].astype(str)

# Home-side financials
home_fin = club_season_fin.rename(columns={
    "team": "home_team",
    "squad_value_eur": "home_squad_value_eur",
    "avg_player_value_eur": "home_avg_player_value_eur",
    "squad_size": "home_squad_size",
    "wage_bill_eur": "home_wage_bill_eur",
    "avg_salary_eur": "home_avg_salary_eur",
    "player_count": "home_wage_player_count",
})
home_fin = home_fin[[
    "season",
    "home_team",
    "home_squad_value_eur",
    "home_avg_player_value_eur",
    "home_squad_size",
    "home_wage_bill_eur",
    "home_avg_salary_eur",
    "home_wage_player_count",
]]

# Away-side financials
away_fin = club_season_fin.rename(columns={
    "team": "away_team",
    "squad_value_eur": "away_squad_value_eur",
    "avg_player_value_eur": "away_avg_player_value_eur",
    "squad_size": "away_squad_size",
    "wage_bill_eur": "away_wage_bill_eur",
    "avg_salary_eur": "away_avg_salary_eur",
    "player_count": "away_wage_player_count",
})
away_fin = away_fin[[
    "season",
    "away_team",
    "away_squad_value_eur",
    "away_avg_player_value_eur",
    "away_squad_size",
    "away_wage_bill_eur",
    "away_avg_salary_eur",
    "away_wage_player_count",
]]

# matches merge in financials
df_fin = df_matches.merge(
    home_fin,
    how="left",
    on=["season", "home_team"],
    validate="m:1",
)

df_fin = df_fin.merge(
    away_fin,
    how="left",
    on=["season", "away_team"],
    validate="m:1",
)

df_fin.head()
# Out:
#    match_id season        date         home_team                away_team  \
# 0     18202   2022  2022-08-05    Crystal Palace                  Arsenal
# 1     18203   2022  2022-08-06            Fulham                Liverpool
# 2     18204   2022  2022-08-06       Bournemouth              Aston Villa
# 3     18205   2022  2022-08-06             Leeds  Wolverhampton Wanderers
# 4     18206   2022  2022-08-06  Newcastle United        Nottingham Forest
#
#   target  home_squad_value_eur  home_avg_player_value_eur  home_squad_size  \
# 0      A           216850000.0               1.668077e+07             13.0
# 1      D           260500000.0               1.628125e+07             16.0
# 2      H           176100000.0               1.600909e+07             11.0
# 3      H           164200000.0               1.492727e+07             11.0
# 4      H           566100000.0               2.573182e+07             22.0
#
#    home_wage_bill_eur  home_avg_salary_eur  home_wage_player_count  \
# 0          79787204.0         3.068739e+06                    26.0
# 1          70660252.0         2.617046e+06                    27.0
# 2          57529223.0         1.743310e+06                    33.0
# 3          69158726.0         2.305291e+06                    30.0
# 4         104547737.0         3.267117e+06                    32.0
#
#    away_squad_value_eur  away_avg_player_value_eur  away_squad_size  \
# 0           904000000.0               5.650000e+07             16.0
# 1           540700000.0               4.505833e+07             12.0
# 2           355000000.0               2.366667e+07             15.0
# 3           120100000.0               1.091818e+07             11.0
# 4           284500000.0               2.370833e+07             12.0
#
#    away_wage_bill_eur  away_avg_salary_eur  away_wage_player_count
# 0         150624114.0         5.793235e+06                    26.0
# 1         193432449.0         6.447748e+06                    30.0
# 2         123236470.0         4.107882e+06                    30.0
# 3          76754701.0         2.257491e+06                    34.0
# 4          86909849.0         2.228458e+06                    39.0

# %%
# Squad value ratios/diffs
df_fin["squad_value_ratio"] = df_fin["home_squad_value_eur"] / df_fin["away_squad_value_eur"]
df_fin["squad_value_diff"]  = df_fin["home_squad_value_eur"] - df_fin["away_squad_value_eur"]

# Avg player value ratios/diffs
df_fin["avg_player_value_ratio"] = df_fin["home_avg_player_value_eur"] / df_fin["away_avg_player_value_eur"]
df_fin["avg_player_value_diff"]  = df_fin["home_avg_player_value_eur"] - df_fin["away_avg_player_value_eur"]

# Wage bill ratios/diffs
df_fin["wage_bill_ratio"] = df_fin["home_wage_bill_eur"] / df_fin["away_wage_bill_eur"]
df_fin["wage_bill_diff"]  = df_fin["home_wage_bill_eur"] - df_fin["away_wage_bill_eur"]

# Avg salary ratios/diffs
df_fin["avg_salary_ratio"] = df_fin["home_avg_salary_eur"] / df_fin["away_avg_salary_eur"]
df_fin["avg_salary_diff"]  = df_fin["home_avg_salary_eur"] - df_fin["away_avg_salary_eur"]

df_fin[[
    "home_team",
    "away_team",
    "home_squad_value_eur",
    "away_squad_value_eur",
    "home_wage_bill_eur",
    "away_wage_bill_eur",
    "squad_value_ratio",
    "wage_bill_ratio",
]].head()
# Out:
#           home_team                away_team  home_squad_value_eur  \
# 0    Crystal Palace                  Arsenal           216850000.0
# 1            Fulham                Liverpool           260500000.0
# 2       Bournemouth              Aston Villa           176100000.0
# 3             Leeds  Wolverhampton Wanderers           164200000.0
# 4  Newcastle United        Nottingham Forest           566100000.0
#
#    away_squad_value_eur  home_wage_bill_eur  away_wage_bill_eur  \
# 0           904000000.0          79787204.0         150624114.0
# 1           540700000.0          70660252.0         193432449.0
# 2           355000000.0          57529223.0         123236470.0
# 3           120100000.0          69158726.0          76754701.0
# 4           284500000.0         104547737.0          86909849.0
#
#    squad_value_ratio  wage_bill_ratio
# 0           0.239878         0.529711
# 1           0.481783         0.365297
# 2           0.496056         0.466820
# 3           1.367194         0.901036
# 4           1.989807         1.202945

# %%
financial_cols = [
    "match_id",
    "season",
    "date",
    "home_team",
    "away_team",
    "target",

    "home_squad_value_eur",
    "away_squad_value_eur",
    "squad_value_ratio",
    "squad_value_diff",

    "home_avg_player_value_eur",
    "away_avg_player_value_eur",
    "avg_player_value_ratio",
    "avg_player_value_diff",

    "home_wage_bill_eur",
    "away_wage_bill_eur",
    "wage_bill_ratio",
    "wage_bill_diff",

    "home_avg_salary_eur",
    "away_avg_salary_eur",
    "avg_salary_ratio",
    "avg_salary_diff",
]

# Only keep columns that actually exist (just in case)
financial_cols = [c for c in financial_cols if c in df_fin.columns]

financial_df = df_fin[financial_cols].copy()
financial_df.head()

OUTPUT_PATH.parent.mkdir(parents=True, exist_ok=True)
financial_df.to_csv(OUTPUT_PATH, index=False)
print("Saved financial dataset to:", OUTPUT_PATH)
# Out:
# Saved financial dataset to: C:\SFUFall2024\CMPT732\pythonProject\The-Beautiful-Game-Oracle-main\data\processed\financial_dataset.csv

# %%
df = pd.read_csv(OUTPUT_PATH)
df.head()
# Out:
#    match_id  season        date         home_team                away_team  \
# 0     18202    2022  2022-08-05    Crystal Palace                  Arsenal
# 1     18203    2022  2022-08-06            Fulham                Liverpool
# 2     18204    2022  2022-08-06       Bournemouth              Aston Villa
# 3     18205    2022  2022-08-06             Leeds  Wolverhampton Wanderers
# 4     18206    2022  2022-08-06  Newcastle United        Nottingham Forest
#
#   target  home_squad_value_eur  away_squad_value_eur  squad_value_ratio  \
# 0      A           216850000.0           904000000.0           0.239878
# 1      D           260500000.0           540700000.0           0.481783
# 2      H           176100000.0           355000000.0           0.496056
# 3      H           164200000.0           120100000.0           1.367194
# 4      H           566100000.0           284500000.0           1.989807
#
#    squad_value_diff  ...  avg_player_value_ratio  avg_player_value_diff  \
# 0      -687150000.0  ...                0.295235          -3.981923e+07
# 1      -280200000.0  ...                0.361337          -2.877708e+07
# 2      -178900000.0  ...                0.676440          -7.657576e+06
# 3        44100000.0  ...                1.367194           4.009091e+06
# 4       281600000.0  ...                1.085349           2.023485e+06
#
#    home_wage_bill_eur  away_wage_bill_eur  wage_bill_ratio  wage_bill_diff  \
# 0          79787204.0         150624114.0         0.529711     -70836910.0
# 1          70660252.0         193432449.0         0.365297    -122772197.0
# 2          57529223.0         123236470.0         0.466820     -65707247.0
# 3          69158726.0          76754701.0         0.901036      -7595975.0
# 4         104547737.0          86909849.0         1.202945      17637888.0
#
#    home_avg_salary_eur  away_avg_salary_eur  avg_salary_ratio  avg_salary_diff
# 0         3.068739e+06         5.793235e+06          0.529711    -2.724497e+06
# 1         2.617046e+06         6.447748e+06          0.405885    -3.830702e+06
# 2         1.743310e+06         4.107882e+06          0.424382    -2.364573e+06
# 3         2.305291e+06         2.257491e+06          1.021174     4.779966e+04
# 4         3.267117e+06         2.228458e+06          1.466089     1.038659e+06
#
# [5 rows x 22 columns]

# %%
financial_features = [
    "squad_value_ratio",
    "squad_value_diff",

    "avg_player_value_ratio",
    "avg_player_value_diff",

    "wage_bill_ratio",
    "wage_bill_diff",

    "avg_salary_ratio",
    "avg_salary_diff",
]

# %%
df["target_label"] = df["target"].map({"H": 0, "D": 1, "A": 2})

# %%
df_fin_ml = df.dropna(subset=financial_features).copy()
print("Rows used:", len(df_fin_ml))

df_fin_ml.loc[:, "season"] = df_fin_ml["season"].astype(int)
print("Seasons present:", df_fin_ml["season"].value_counts().sort_index())

TEST_SEASON = 2025
VAL_SEASON = 2024

test_mask = df_fin_ml["season"] == TEST_SEASON
val_mask  = df_fin_ml["season"] == VAL_SEASON
train_mask = df_fin_ml["season"] < VAL_SEASON   # everything before 2024

print("Train matches:", train_mask.sum())
print("Val matches:", val_mask.sum())
print("Test matches:", test_mask.sum())

# no overlap
assert not (train_mask & val_mask).any()
assert not (train_mask & test_mask).any()
assert not (val_mask & test_mask).any()

X = df_fin_ml[financial_features]
y = df_fin_ml["target_label"]

X_train, X_val, X_test = X[train_mask], X[val_mask], X[test_mask]
y_train, y_val, y_test = y[train_mask], y[val_mask], y[test_mask]

print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("X_test shape:", X_test.shape)
# Out:
# Rows used: 1212
# Seasons present: season
# 2022    380
# 2023    342
# 2024    380
# 2025    110
# Name: count, dtype: int64
# Train matches: 722
# Val matches: 380
# Test matches: 110
# X_train shape: (722, 8)
# X_val shape: (380, 8)
# X_test shape: (110, 8)

# %%
from xgboost import XGBClassifier

fin_xgb = XGBClassifier(
    objective="multi:softprob",
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.9, 
    colsample_bytree=0.9, 
    eval_metric="mlogloss",
    random_state=42,
    early_stopping_rounds=40, 
)

fin_xgb.fit(
    X_train,
    y_train,
    eval_set=[(X_val, y_val)],
    verbose=False,
)

print("Best iteration:", fin_xgb.best_iteration)
# Out:
# Best iteration: 20

# %%
from sklearn.metrics import accuracy_score, log_loss, classification_report

for split_name, X_split, y_split in [
    ("Train", X_train, y_train),
    ("Val",   X_val,   y_val),
    ("Test",  X_test,  y_test),
]:
    y_pred  = fin_xgb.predict(X_split)
    y_proba = fin_xgb.predict_proba(X_split)
    acc = accuracy_score(y_split, y_pred)
    ll  = log_loss(y_split, y_proba)
    print(f"{split_name} accuracy: {acc:.3f}, log loss: {ll:.3f}")

print("\nTest classification report:")
print(classification_report(y_test, fin_xgb.predict(X_test)))
# Out:
# Train accuracy: 0.831, log loss: 0.756
# Val accuracy: 0.495, log loss: 1.025
# Test accuracy: 0.509, log loss: 1.019
#
# Test classification report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.76      0.68        58
#            1       0.25      0.12      0.17        24
#            2       0.35      0.32      0.33        28
#
#     accuracy                           0.51       110
#    macro avg       0.40      0.40      0.39       110
# weighted avg       0.46      0.51      0.48       110

# %%
import matplotlib.pyplot as plt

importances = fin_xgb.feature_importances_
plt.barh(financial_features, importances)
plt.title("Financial Model Feature Importance")
plt.show()

# %%
import pandas as pd
import os

os.makedirs("outputs", exist_ok=True)

# Probabilities and class predictions for financial model
fin_proba = fin_xgb.predict_proba(X_test)
fin_pred = fin_xgb.predict(X_test)

test_rows = df_fin_ml.loc[test_mask].reset_index(drop=True)

fin_preds = pd.DataFrame({
    "match_id":   test_rows["match_id"].values,
    "season":     test_rows["season"].values,
    "match_date": test_rows["date"].values,
    "home_team":  test_rows["home_team"].values,
    "away_team":  test_rows["away_team"].values,
    
    "true_label": y_test.values,       
    
    "fin_pred_class": fin_pred,
    "fin_p_home": fin_proba[:, 0],
    "fin_p_draw": fin_proba[:, 1],
    "fin_p_away": fin_proba[:, 2],
})

fin_preds.to_csv("outputs/financial_lens_predictions.csv", index=False)
print("Saved: outputs/financial_lens_predictions.csv")
# Out:
# Saved: outputs/financial_lens_predictions.csv

# %%
from pathlib import Path

perf_raw_path = Path("performance_test_predictions.csv")
mkt_raw_path  = Path("market_test_predictions.csv")
fin_path      = Path("outputs/financial_lens_predictions.csv")

perf_raw = pd.read_csv(perf_raw_path)
mkt_raw  = pd.read_csv(mkt_raw_path)
fin      = pd.read_csv(fin_path)

def prep_lens(df, prefix: str) -> pd.DataFrame:
    cols = [
        "match_id", "season", "match_date",
        "home_team", "away_team",
        "target", "predicted", "home_prob", "draw_prob", "away_prob",
    ]
    df = df[cols].copy()
    df = df.rename(columns={
        "target":    "true_label",
        "predicted": f"{prefix}_pred_class",
        "home_prob": f"{prefix}_p_home",
        "draw_prob": f"{prefix}_p_draw",
        "away_prob": f"{prefix}_p_away",
    })
    return df

perf = prep_lens(perf_raw, "perf")
mkt  = prep_lens(mkt_raw,  "mkt")


merge_keys = ["match_id", "season", "match_date", "home_team", "away_team", "true_label"]

pm = perf.merge(mkt, on=merge_keys, how="inner")
pmf = pm.merge(fin, on=merge_keys, how="inner")

print("Combined shape:", pmf.shape)
pmf.head()
# Out:
# Combined shape: (60, 18)
#    match_id  season  match_date          home_team                away_team  \
# 0     28832    2025  2025-09-27              Leeds              Bournemouth
# 1     28835    2025  2025-09-27          Tottenham  Wolverhampton Wanderers
# 2     28834    2025  2025-09-27  Nottingham Forest               Sunderland
# 3     28833    2025  2025-09-27    Manchester City                  Burnley
# 4     28829    2025  2025-09-27            Chelsea                 Brighton
#
#    true_label  perf_pred_class  perf_p_home  perf_p_draw  perf_p_away  \
# 0           1                2     0.251638     0.292380     0.455981
# 1           1                0     0.489620     0.277729     0.232651
# 2           2                2     0.342719     0.289626     0.367655
# 3           0                0     0.663350     0.157921     0.178729
# 4           2                0     0.500722     0.187959     0.311319
#
#    mkt_pred_class  mkt_p_home  mkt_p_draw  mkt_p_away  fin_pred_class  \
# 0               0    0.538278    0.188522    0.273200               0
# 1               2    0.203566    0.211107    0.585327               0
# 2               2    0.167225    0.348801    0.483974               0
# 3               0    0.864814    0.091462    0.043723               0
# 4               2    0.247306    0.300647    0.452047               0
#
#    fin_p_home  fin_p_draw  fin_p_away
# 0    0.463613    0.274977    0.261410
# 1    0.619868    0.192735    0.187397
# 2    0.587133    0.215776    0.197090
# 3    0.552894    0.189782    0.257324
# 4    0.532466    0.198480    0.269054

# %%
pmf.to_csv("pmf.csv", index=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.calibration import calibration_curve

def plot_calibration_for_home(pmf, n_bins=10):
    # True: home win = 1, else 0
    y_true_home = (pmf["true_label"] == 0).astype(int).values

    lenses = {
        "Performance": pmf["perf_p_home"].values,
        "Market":      pmf["mkt_p_home"].values,
        "Financial":   pmf["fin_p_home"].values,
    }

    plt.figure(figsize=(6, 6))
    
    # Perfect calibration line
    plt.plot([0, 1], [0, 1])
    
    for name, probs in lenses.items():
        frac_pos, mean_pred = calibration_curve(
            y_true_home,
            probs,
            n_bins=n_bins,
            strategy="uniform"
        )
        plt.plot(mean_pred, frac_pos, marker="o", label=name)

    plt.xlabel("Predicted probability (home win)")
    plt.ylabel("Actual frequency (home win)")
    plt.title("Calibration Curve – Home Win (Test Set)")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_calibration_for_home(pmf)

# %%
def plot_home_prob_distributions(pmf, bins=20):
    plt.figure(figsize=(8, 5))

    plt.hist(pmf["perf_p_home"], bins=bins, alpha=0.5, label="Performance")
    plt.hist(pmf["mkt_p_home"],  bins=bins, alpha=0.5, label="Market")
    plt.hist(pmf["fin_p_home"],  bins=bins, alpha=0.5, label="Financial")

    plt.xlabel("Predicted P(Home win)")
    plt.ylabel("Count (matches)")
    plt.title("Distribution of Home Win Probabilities – Test Set")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_home_prob_distributions(pmf)

# %%
from sklearn.metrics import confusion_matrix

def plot_lens_disagreement(pmf):
    # 0 = home, 1 = draw, 2 = away
    y_perf = pmf["perf_pred_class"].values
    y_mkt  = pmf["mkt_pred_class"].values

    cm = confusion_matrix(y_perf, y_mkt, labels=[0, 1, 2])

    plt.figure(figsize=(5, 4))
    plt.imshow(cm, interpolation="nearest")
    plt.title("Lens Disagreement – Performance vs Market")
    plt.colorbar()
    tick_marks = np.arange(3)
    labels = ["Home", "Draw", "Away"]
    plt.xticks(tick_marks, labels)
    plt.yticks(tick_marks, labels)
    plt.xlabel("Market predicted class")
    plt.ylabel("Performance predicted class")

    # Add counts as text
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, cm[i, j], ha="center", va="center")

    plt.tight_layout()
    plt.show()

plot_lens_disagreement(pmf)

# %%
def compute_running_accuracy(true_labels, pred_labels):
    correct = (true_labels == pred_labels).astype(int)
    cum_correct = np.cumsum(correct)
    idx = np.arange(1, len(correct) + 1)
    return cum_correct / idx

def plot_cumulative_accuracy(pmf):
    # Sort by date to make it chronological
    pmf_sorted = pmf.sort_values("match_date").reset_index(drop=True)

    y_true = pmf_sorted["true_label"].values
    y_perf = pmf_sorted["perf_pred_class"].values
    y_mkt  = pmf_sorted["mkt_pred_class"].values
    y_fin  = pmf_sorted["fin_pred_class"].values

    acc_perf = compute_running_accuracy(y_true, y_perf)
    acc_mkt  = compute_running_accuracy(y_true, y_mkt)
    acc_fin  = compute_running_accuracy(y_true, y_fin)

    x = np.arange(len(pmf_sorted))

    plt.figure(figsize=(8, 5))
    plt.plot(x, acc_perf, label="Performance")
    plt.plot(x, acc_mkt,  label="Market")
    plt.plot(x, acc_fin,  label="Financial")

    plt.xlabel("Match index (chronological test set)")
    plt.ylabel("Cumulative accuracy")
    plt.title("Cumulative Accuracy Over Test Season")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_cumulative_accuracy(pmf)

# %%
plt.figure(figsize=(6,4))
plt.barh(financial_features, fin_xgb.feature_importances_)
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Financial Lens Feature Importance")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

y_proba_test = fin_xgb.predict_proba(X_test)
y_pred_test = np.argmax(y_proba_test, axis=1)

class_names = ["Home win", "Draw", "Away win"]

fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

for k, ax in enumerate(axes):
    ax.hist(y_proba_test[:, k], bins=15, alpha=0.8)
    ax.set_title(f"P({class_names[k]})")
    ax.set_xlabel("Predicted probability")
    if k == 0:
        ax.set_ylabel("Count (matches)")

fig.suptitle("Financial Lens – Class-wise Probability Distributions (Test Set)", y=1.05)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

class_names = ["Home", "Draw", "Away"]

# Normalized confusion matrix
cm = confusion_matrix(y_test, y_pred_test, labels=[0, 1, 2], normalize='true')

fig, ax = plt.subplots(figsize=(5, 4))
im = ax.imshow(cm, cmap="Blues")  # ← BLUE COLOR MAP

# Axes labels
ax.set_xticks(range(len(class_names)))
ax.set_yticks(range(len(class_names)))
ax.set_xticklabels(class_names)
ax.set_yticklabels(class_names)

ax.set_xlabel("Predicted class")
ax.set_ylabel("True class")
ax.set_title("Financial Lens – Normalized Confusion Matrix")

# Annotate each cell
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        value = cm[i, j]
        ax.text(
            j, i, f"{value:.2f}",
            ha="center", va="center",
            color="white" if value > 0.5 else "black",
            fontsize=10
        )

# Add colorbar
cbar = plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cbar.ax.set_ylabel('Normalized value', rotation=270, labelpad=12)

plt.tight_layout()
plt.show()
